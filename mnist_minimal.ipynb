# %%
import torch
import torch.nn as nn
from tqdm import tqdm

from dataloaders.MNISTDataset import get_dataloaders
from nn.Net import Net
from nn.ControlNet import ControlNet
from utils.colored_prints import *

# %%
train_loader, test_loader = get_dataloaders(0)

# %%
num_epochs = 50
inner_epochs = 156
learning_rate = 0.001
control_lr = 0.001
control_threshold = 1e-3
l1_lambda = 0.0


input_size_net = 28 * 28
hidden_size_net = 100
output_size_net = 10
hidden_size_control = 100

input_size_control = input_size_net + hidden_size_net + output_size_net

# %%
net = Net(
    input_size=input_size_net,
    hidden_size=hidden_size_net,
    output_size=output_size_net,
    softmax=False,
)

# %%
control_net = ControlNet(
    input_size=input_size_control,
    hidden_size=hidden_size_control,
    output_size=hidden_size_net + output_size_net,
)

# %%
criterion = nn.CrossEntropyLoss()
control_optimizer = torch.optim.Adam(control_net.parameters(), lr=float(control_lr))
net_optimizer = torch.optim.Adam(net.parameters(), lr=float(learning_rate))

# %%
def evaluate_model(net, control_net, test_loader):
    correct = 0
    total = 0

    with torch.no_grad():
        for batch_data, batch_labels in test_loader:
            net.reset_control_signals()
            h1 = net.layer1(net.flatten(batch_data))
            output = net(batch_data)
            current_activities = torch.cat([net.flatten(batch_data), h1, output], dim=1)

            control_signals = control_net(current_activities)
            net.set_control_signals(control_signals)
            output = net(batch_data)

            predictions = output.max(dim=1).indices
            total += batch_labels.size(0)
            correct += (predictions == batch_labels).sum().item()

    accuracy = 100 * correct / total

    return accuracy

# %%
def train_model(
    net,
    control_net,
    train_loader,
    criterion,
    control_optimizer,
    net_optimizer,
    control_threshold,
    l1_lambda,
    verbose = False
):
    pbar = tqdm(range(num_epochs), desc=f"Epochs", leave=False)

    for epoch in pbar:
        batch_losses = []

        for batch_data, batch_labels in train_loader:
            inner_epoch_correct = None
            inner_epoch_cvg = None

            # Get current network activities
            with torch.no_grad():
                net.reset_control_signals()
                h1 = net.layer1(net.flatten(batch_data))
                output = net(batch_data)
                current_activities = torch.cat(
                    [net.flatten(batch_data), h1, output], dim=1
                )

            old_loss = float("inf")
            for inner_epoch in range(100):
                control_optimizer.zero_grad()
                net_optimizer.zero_grad()  # TODO: Do I need this?

                control_signals = control_net(current_activities)
                net.set_control_signals(control_signals)

                output = net(batch_data)  # net is excluded from the graph

                # hardcoded label
                control_loss = criterion(output, batch_labels)

                # l1_reg = l1_lambda * (net(data) - label).abs().sum(dim=1).mean()

                control_loss.backward()

                control_optimizer.step()
                net_optimizer.step()

                if (
                    torch.argmax(output, dim=1) == batch_labels
                ).all() and inner_epoch_correct is None:
                    inner_epoch_correct = inner_epoch

                if abs(old_loss - control_loss.item()) < control_threshold:
                    inner_epoch_cvg = inner_epoch
                    break

                old_loss = control_loss.item()

            acc = (
                torch.sum(torch.argmax(output, dim=1) == batch_labels).item()
                / batch_labels.size(0)
                * 100
            )

            if verbose:
                if acc < 80:
                    print_error(f"Fail! {acc:.2f}% at inner_epoch {inner_epoch}")
                else:
                    print_info(f"Win {acc:.2f}% at inner_epoch {inner_epoch}")

                if inner_epoch_cvg is None:
                    print(f"Failed to converge")
                else:
                    print(f"Converged at inner epoch {inner_epoch_cvg}")

                print("\n")

            if control_loss.item() > 0.01:
                batch_losses.append(control_loss.item())
                with torch.no_grad():
                    control_signals = control_net(current_activities)
                    # a.shape is [batch_size, hidden_size + output_size]
                    a1 = control_signals[:, : net.hidden_size]
                    a2 = control_signals[:, net.hidden_size :]

                    # Sander said, we can use 1.0 as the baseline
                    baseline_a1 = torch.ones_like(a1)
                    baseline_a2 = torch.ones_like(a2)
                    a1_diff = a1 - baseline_a1
                    a2_diff = a2 - baseline_a2

                    # Layer 1 weight update
                    x = net.flatten(batch_data)
                    phi = net.hidden_activations(net.layer1(x))
                    r_post_adjusted = phi * a1 * a1_diff
                    dw = r_post_adjusted.T @ x
                    dw = dw / x.shape[0]
                    net.layer1.weight.grad = torch.clamp(dw, min=-1, max=1)

                    # Layer 2 weight update
                    x2 = net.hidden_activations(net.layer1(net.flatten(batch_data)))
                    phi2 = net.output_activations(net.layer2(x2))
                    r_post_adjusted2 = phi2 * a2 * a2_diff
                    dw2 = r_post_adjusted2.T @ x2
                    dw2 = dw2 / x2.shape[0]
                    net.layer2.weight.grad = torch.clamp(dw2, min=-1, max=1)

                    net_optimizer.step()
        epoch_loss = sum(batch_losses) / len(batch_losses) if batch_losses else 0
        accuracy = evaluate_model(net, control_net, test_loader)
        print(f"Epoch {epoch}  Loss: {epoch_loss}  Accuracy: {accuracy:.2f}%")

# %%
train_model(
    net,
    control_net,
    train_loader,
    criterion,
    control_optimizer,
    net_optimizer,
    control_threshold,
    l1_lambda,
)
# Out:
# Epochs:   0%|          | 0/50 [00:00<?, ?it/s]
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 53
# Converged at inner epoch 53
#
#
# [INFO] Win 100.00% at inner_epoch 58
# Converged at inner epoch 58
#
#
# [INFO] Win 100.00% at inner_epoch 51
# Converged at inner epoch 51
#
#
# [INFO] Win 100.00% at inner_epoch 65
# Converged at inner epoch 65
#
#
# [INFO] Win 100.00% at inner_epoch 51
# Converged at inner epoch 51
#
#
# [INFO] Win 100.00% at inner_epoch 60
# Converged at inner epoch 60
#
#
# [INFO] Win 100.00% at inner_epoch 55
# Converged at inner epoch 55
#
#
# [INFO] Win 90.62% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 68
# Converged at inner epoch 68
#
#
# [INFO] Win 100.00% at inner_epoch 42
# Converged at inner epoch 42
#
#
# [INFO] Win 100.00% at inner_epoch 57
# Converged at inner epoch 57
#
#
# [INFO] Win 100.00% at inner_epoch 51
# Converged at inner epoch 51
#
#
# [INFO] Win 100.00% at inner_epoch 54
# Converged at inner epoch 54
#
#
# [INFO] Win 100.00% at inner_epoch 51
# Converged at inner epoch 51
#
#
# [INFO] Win 96.88% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 68
# Converged at inner epoch 68
#
#
# [INFO] Win 100.00% at inner_epoch 52
# Converged at inner epoch 52
#
#
# [INFO] Win 100.00% at inner_epoch 36
# Converged at inner epoch 36
#
#
# [INFO] Win 100.00% at inner_epoch 42
# Converged at inner epoch 42
#
#
# [INFO] Win 84.38% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 47
# Converged at inner epoch 47
#
#
# [INFO] Win 100.00% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 100.00% at inner_epoch 52
# Converged at inner epoch 52
#
#
# [INFO] Win 100.00% at inner_epoch 31
# Converged at inner epoch 31
#
#
# [INFO] Win 100.00% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 96.88% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 35
# Converged at inner epoch 35
#
#
# [INFO] Win 100.00% at inner_epoch 42
# Converged at inner epoch 42
#
#
# [INFO] Win 100.00% at inner_epoch 49
# Converged at inner epoch 49
#
#
# [INFO] Win 100.00% at inner_epoch 53
# Converged at inner epoch 53
#
#
# [INFO] Win 100.00% at inner_epoch 36
# Converged at inner epoch 36
#
#
# [INFO] Win 100.00% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 96.88% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 100.00% at inner_epoch 44
# Converged at inner epoch 44
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 100.00% at inner_epoch 36
# Converged at inner epoch 36
#
#
# [INFO] Win 100.00% at inner_epoch 31
# Converged at inner epoch 31
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 96.88% at inner_epoch 9
# Converged at inner epoch 9
#
#
# [INFO] Win 100.00% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 100.00% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 100.00% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 100.00% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 93.75% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 24
# Converged at inner epoch 24
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 100.00% at inner_epoch 62
# Converged at inner epoch 62
#
#
# [INFO] Win 100.00% at inner_epoch 31
# Converged at inner epoch 31
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 93.75% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 87.50% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 96.88% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 100.00% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 51
# Converged at inner epoch 51
#
#
# [INFO] Win 100.00% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 93.75% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 96.88% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 93.75% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 93.75% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 81.25% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 96.88% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 96.88% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 40
# Converged at inner epoch 40
#
#
# [INFO] Win 100.00% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 32
# Converged at inner epoch 32
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 93.75% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 24
# Converged at inner epoch 24
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 42
# Converged at inner epoch 42
#
#
# [INFO] Win 100.00% at inner_epoch 46
# Converged at inner epoch 46
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 100.00% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 35
# Converged at inner epoch 35
#
#
# [INFO] Win 100.00% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 96.88% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 96.88% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 100.00% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 100.00% at inner_epoch 48
# Converged at inner epoch 48
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 93.75% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 96.88% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 96.88% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 96.88% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 49
# Converged at inner epoch 49
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 93.75% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 100.00% at inner_epoch 57
# Converged at inner epoch 57
#
#
# [INFO] Win 100.00% at inner_epoch 68
# Converged at inner epoch 68
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 87.50% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 96.88% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 96.88% at inner_epoch 31
# Converged at inner epoch 31
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 96.88% at inner_epoch 41
# Converged at inner epoch 41
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 52
# Converged at inner epoch 52
#
#
# [INFO] Win 96.88% at inner_epoch 31
# Converged at inner epoch 31
#
#
# [INFO] Win 100.00% at inner_epoch 35
# Converged at inner epoch 35
#
#
# [INFO] Win 100.00% at inner_epoch 35
# Converged at inner epoch 35
#
#
# [INFO] Win 100.00% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 100.00% at inner_epoch 32
# Converged at inner epoch 32
#
#
# [INFO] Win 100.00% at inner_epoch 39
# Converged at inner epoch 39
#
#
# [INFO] Win 96.88% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 96.88% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 93.75% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 100.00% at inner_epoch 24
# Converged at inner epoch 24
#
#
# [INFO] Win 87.50% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 93.75% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 32
# Converged at inner epoch 32
#
#
# [INFO] Win 93.75% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 96.88% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 100.00% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 90.62% at inner_epoch 3
# Converged at inner epoch 3
#
#
# [INFO] Win 96.88% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 93.75% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 100.00% at inner_epoch 32
# Converged at inner epoch 32
#
#
# [INFO] Win 100.00% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 96.88% at inner_epoch 11
# Converged at inner epoch 11
#
#
# [INFO] Win 100.00% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 90.62% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 96.88% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 61
# Converged at inner epoch 61
#
#
# [INFO] Win 93.75% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 96.88% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 11
# Converged at inner epoch 11
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 96.88% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 90.62% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 96.88% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 100.00% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 93.75% at inner_epoch 40
# Converged at inner epoch 40
#
#
# [INFO] Win 100.00% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 100.00% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 100.00% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 96.88% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 100.00% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 100.00% at inner_epoch 47
# Converged at inner epoch 47
#
#
# [INFO] Win 96.88% at inner_epoch 39
# Converged at inner epoch 39
#
#
# [INFO] Win 100.00% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 93.75% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 100.00% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 96.88% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 83
# Converged at inner epoch 83
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 93.75% at inner_epoch 9
# Converged at inner epoch 9
#
#
# [INFO] Win 100.00% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 100.00% at inner_epoch 47
# Converged at inner epoch 47
#
#
# [INFO] Win 100.00% at inner_epoch 41
# Converged at inner epoch 41
#
#
# [INFO] Win 100.00% at inner_epoch 49
# Converged at inner epoch 49
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 93.75% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 93.75% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 96.88% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 100.00% at inner_epoch 42
# Converged at inner epoch 42
#
#
# [INFO] Win 90.62% at inner_epoch 45
# Converged at inner epoch 45
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 96.88% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 40
# Converged at inner epoch 40
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 96.88% at inner_epoch 38
# Converged at inner epoch 38
#
#
# [INFO] Win 90.62% at inner_epoch 3
# Converged at inner epoch 3
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 93.75% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 93.75% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 100.00% at inner_epoch 42
# Converged at inner epoch 42
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 32
# Converged at inner epoch 32
#
#
# [INFO] Win 93.75% at inner_epoch 3
# Converged at inner epoch 3
#
#
# [INFO] Win 87.50% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 41
# Converged at inner epoch 41
#
#
# [INFO] Win 100.00% at inner_epoch 45
# Converged at inner epoch 45
#
#
# [INFO] Win 100.00% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 96.88% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 52
# Converged at inner epoch 52
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 100.00% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 96.88% at inner_epoch 38
# Converged at inner epoch 38
#
#
# [INFO] Win 100.00% at inner_epoch 81
# Converged at inner epoch 81
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 93.75% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 36
# Converged at inner epoch 36
#
#
# [INFO] Win 100.00% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 41
# Converged at inner epoch 41
#
#
# [INFO] Win 90.62% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 69
# Converged at inner epoch 69
#
#
# [INFO] Win 93.75% at inner_epoch 31
# Converged at inner epoch 31
#
#
# [INFO] Win 93.75% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 100.00% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 93.75% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 11
# Converged at inner epoch 11
#
#
# [INFO] Win 100.00% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 24
# Converged at inner epoch 24
#
#
# [INFO] Win 93.75% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 100.00% at inner_epoch 46
# Converged at inner epoch 46
#
#
# [INFO] Win 100.00% at inner_epoch 67
# Converged at inner epoch 67
#
#
# [INFO] Win 90.62% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 96.88% at inner_epoch 31
# Converged at inner epoch 31
#
#
# [INFO] Win 100.00% at inner_epoch 44
# Converged at inner epoch 44
#
#
# [INFO] Win 100.00% at inner_epoch 32
# Converged at inner epoch 32
#
#
# [ERROR] Fail! 78.12% at inner_epoch 3
# Converged at inner epoch 3
#
#
# [INFO] Win 100.00% at inner_epoch 48
# Converged at inner epoch 48
#
#
# [INFO] Win 100.00% at inner_epoch 41
# Converged at inner epoch 41
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 93.75% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 46
# Converged at inner epoch 46
#
#
# [INFO] Win 100.00% at inner_epoch 31
# Converged at inner epoch 31
#
#
# [INFO] Win 100.00% at inner_epoch 35
# Converged at inner epoch 35
#
#
# [INFO] Win 100.00% at inner_epoch 31
# Converged at inner epoch 31
#
#
# [INFO] Win 96.88% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 39
# Converged at inner epoch 39
#
#
# [INFO] Win 96.88% at inner_epoch 83
# Converged at inner epoch 83
#
#
# [INFO] Win 100.00% at inner_epoch 35
# Converged at inner epoch 35
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 90.62% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 93.75% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 24
# Converged at inner epoch 24
#
#
# [INFO] Win 93.75% at inner_epoch 3
# Converged at inner epoch 3
#
#
# [INFO] Win 90.62% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 96.88% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 96.88% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 96.88% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 32
# Converged at inner epoch 32
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 100.00% at inner_epoch 44
# Converged at inner epoch 44
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 93.75% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 36
# Converged at inner epoch 36
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 93.75% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 96.88% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 37
# Converged at inner epoch 37
#
#
# [INFO] Win 96.88% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 44
# Converged at inner epoch 44
#
#
# [INFO] Win 96.88% at inner_epoch 31
# Converged at inner epoch 31
#
#
# [INFO] Win 100.00% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 100.00% at inner_epoch 39
# Converged at inner epoch 39
#
#
# [INFO] Win 100.00% at inner_epoch 51
# Converged at inner epoch 51
#
#
# [INFO] Win 100.00% at inner_epoch 11
# Converged at inner epoch 11
#
#
# [INFO] Win 93.75% at inner_epoch 37
# Converged at inner epoch 37
#
#
# [INFO] Win 96.88% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 80
# Converged at inner epoch 80
#
#
# [INFO] Win 100.00% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 100.00% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 100.00% at inner_epoch 45
# Converged at inner epoch 45
#
#
# [INFO] Win 96.88% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 100.00% at inner_epoch 48
# Converged at inner epoch 48
#
#
# [INFO] Win 93.75% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 100.00% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 41
# Converged at inner epoch 41
#
#
# [INFO] Win 100.00% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 93.75% at inner_epoch 35
# Converged at inner epoch 35
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 100.00% at inner_epoch 50
# Converged at inner epoch 50
#
#
# [INFO] Win 100.00% at inner_epoch 45
# Converged at inner epoch 45
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 96.88% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 93.75% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 100.00% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 96.88% at inner_epoch 32
# Converged at inner epoch 32
#
#
# [INFO] Win 100.00% at inner_epoch 51
# Converged at inner epoch 51
#
#
# [INFO] Win 100.00% at inner_epoch 48
# Converged at inner epoch 48
#
#
# [INFO] Win 90.62% at inner_epoch 36
# Converged at inner epoch 36
#
#
# [INFO] Win 100.00% at inner_epoch 41
# Converged at inner epoch 41
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 96.88% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 93.75% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 93.75% at inner_epoch 42
# Converged at inner epoch 42
#
#
# [INFO] Win 96.88% at inner_epoch 45
# Converged at inner epoch 45
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 36
# Converged at inner epoch 36
#
#
# [INFO] Win 93.75% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 93.75% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 24
# Converged at inner epoch 24
#
#
# [INFO] Win 93.75% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 93.75% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 93.75% at inner_epoch 99
# Failed to converge
#
#
# [INFO] Win 93.75% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 35
# Converged at inner epoch 35
#
#
# [INFO] Win 100.00% at inner_epoch 9
# Converged at inner epoch 9
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 48
# Converged at inner epoch 48
#
#
# [INFO] Win 100.00% at inner_epoch 46
# Converged at inner epoch 46
#
#
# [INFO] Win 100.00% at inner_epoch 40
# Converged at inner epoch 40
#
#
# [INFO] Win 96.88% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 3
# Converged at inner epoch 3
#
#
# [INFO] Win 100.00% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 90.62% at inner_epoch 32
# Converged at inner epoch 32
#
#
# [INFO] Win 96.88% at inner_epoch 69
# Converged at inner epoch 69
#
#
# [INFO] Win 96.88% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 36
# Converged at inner epoch 36
#
#
# [INFO] Win 100.00% at inner_epoch 32
# Converged at inner epoch 32
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 100.00% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 100.00% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 93.75% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 96.88% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 55
# Converged at inner epoch 55
#
#
# [INFO] Win 100.00% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 96.88% at inner_epoch 46
# Converged at inner epoch 46
#
#
# [INFO] Win 93.75% at inner_epoch 47
# Converged at inner epoch 47
#
#
# [INFO] Win 100.00% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 100.00% at inner_epoch 44
# Converged at inner epoch 44
#
#
# [INFO] Win 100.00% at inner_epoch 44
# Converged at inner epoch 44
#
#
# [INFO] Win 96.88% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 96.88% at inner_epoch 58
# Converged at inner epoch 58
#
#
# [INFO] Win 96.88% at inner_epoch 50
# Converged at inner epoch 50
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 96.88% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 68
# Converged at inner epoch 68
#
#
# [INFO] Win 100.00% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 100.00% at inner_epoch 39
# Converged at inner epoch 39
#
#
# [INFO] Win 90.62% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 93.75% at inner_epoch 38
# Converged at inner epoch 38
#
#
# [INFO] Win 100.00% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 100.00% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 100.00% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 100.00% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 100.00% at inner_epoch 60
# Converged at inner epoch 60
#
#
# [INFO] Win 100.00% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 96.88% at inner_epoch 37
# Converged at inner epoch 37
#
#
# [INFO] Win 100.00% at inner_epoch 35
# Converged at inner epoch 35
#
#
# [INFO] Win 100.00% at inner_epoch 69
# Converged at inner epoch 69
#
#
# [INFO] Win 93.75% at inner_epoch 58
# Converged at inner epoch 58
#
#
# [INFO] Win 100.00% at inner_epoch 67
# Converged at inner epoch 67
#
#
# [INFO] Win 87.50% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 47
# Converged at inner epoch 47
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 51
# Converged at inner epoch 51
#
#
# [INFO] Win 90.62% at inner_epoch 39
# Converged at inner epoch 39
#
#
# [INFO] Win 100.00% at inner_epoch 35
# Converged at inner epoch 35
#
#
# [INFO] Win 100.00% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 96.88% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 49
# Converged at inner epoch 49
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 96.88% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 100.00% at inner_epoch 9
# Converged at inner epoch 9
#
#
# [INFO] Win 96.88% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 93.75% at inner_epoch 48
# Converged at inner epoch 48
#
#
# [INFO] Win 93.75% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 32
# Converged at inner epoch 32
#
#
# [INFO] Win 93.75% at inner_epoch 47
# Converged at inner epoch 47
#
#
# [INFO] Win 100.00% at inner_epoch 39
# Converged at inner epoch 39
#
#
# [INFO] Win 96.88% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 58
# Converged at inner epoch 58
#
#
# [INFO] Win 100.00% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 90.62% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 100.00% at inner_epoch 69
# Converged at inner epoch 69
#
#
# [INFO] Win 93.75% at inner_epoch 37
# Converged at inner epoch 37
#
#
# [INFO] Win 90.62% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 96.88% at inner_epoch 31
# Converged at inner epoch 31
#
#
# [INFO] Win 96.88% at inner_epoch 59
# Converged at inner epoch 59
#
#
# [INFO] Win 100.00% at inner_epoch 62
# Converged at inner epoch 62
#
#
# [INFO] Win 100.00% at inner_epoch 40
# Converged at inner epoch 40
#
#
# [INFO] Win 100.00% at inner_epoch 49
# Converged at inner epoch 49
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 96.88% at inner_epoch 56
# Converged at inner epoch 56
#
#
# [INFO] Win 90.62% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 90.62% at inner_epoch 38
# Converged at inner epoch 38
#
#
# [INFO] Win 100.00% at inner_epoch 41
# Converged at inner epoch 41
#
#
# [INFO] Win 93.75% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 93.75% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 100.00% at inner_epoch 42
# Converged at inner epoch 42
#
#
# [INFO] Win 96.88% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 24
# Converged at inner epoch 24
#
#
# [INFO] Win 96.88% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 93.75% at inner_epoch 44
# Converged at inner epoch 44
#
#
# [INFO] Win 96.88% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 100.00% at inner_epoch 37
# Converged at inner epoch 37
#
#
# [INFO] Win 87.50% at inner_epoch 41
# Converged at inner epoch 41
#
#
# [INFO] Win 87.50% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [ERROR] Fail! 78.12% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 52
# Converged at inner epoch 52
#
#
# [INFO] Win 93.75% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 93.75% at inner_epoch 99
# Failed to converge
#
#
# [INFO] Win 100.00% at inner_epoch 45
# Converged at inner epoch 45
#
#
# [INFO] Win 100.00% at inner_epoch 65
# Converged at inner epoch 65
#
#
# [INFO] Win 100.00% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 39
# Converged at inner epoch 39
#
#
# [INFO] Win 100.00% at inner_epoch 52
# Converged at inner epoch 52
#
#
# [INFO] Win 100.00% at inner_epoch 53
# Converged at inner epoch 53
#
#
# [INFO] Win 100.00% at inner_epoch 99
# Failed to converge
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 52
# Converged at inner epoch 52
#
#
# [INFO] Win 100.00% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 68
# Converged at inner epoch 68
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 100.00% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 93.75% at inner_epoch 41
# Converged at inner epoch 41
#
#
# [INFO] Win 100.00% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 100.00% at inner_epoch 32
# Converged at inner epoch 32
#
#
# [INFO] Win 100.00% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 90.62% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 96.88% at inner_epoch 41
# Converged at inner epoch 41
#
#
# [INFO] Win 100.00% at inner_epoch 56
# Converged at inner epoch 56
#
#
# [INFO] Win 100.00% at inner_epoch 37
# Converged at inner epoch 37
#
#
# [INFO] Win 96.88% at inner_epoch 52
# Converged at inner epoch 52
#
#
# [INFO] Win 100.00% at inner_epoch 69
# Converged at inner epoch 69
#
#
# [INFO] Win 100.00% at inner_epoch 46
# Converged at inner epoch 46
#
#
# [INFO] Win 90.62% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 24
# Converged at inner epoch 24
#
#
# [INFO] Win 96.88% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 11
# Converged at inner epoch 11
#
#
# [INFO] Win 90.62% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 96.88% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 100.00% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 96.88% at inner_epoch 46
# Converged at inner epoch 46
#
#
# [INFO] Win 100.00% at inner_epoch 45
# Converged at inner epoch 45
#
#
# [INFO] Win 100.00% at inner_epoch 51
# Converged at inner epoch 51
#
#
# [INFO] Win 96.88% at inner_epoch 39
# Converged at inner epoch 39
#
#
# [INFO] Win 100.00% at inner_epoch 47
# Converged at inner epoch 47
#
#
# [INFO] Win 100.00% at inner_epoch 48
# Converged at inner epoch 48
#
#
# [INFO] Win 96.88% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 96.88% at inner_epoch 54
# Converged at inner epoch 54
#
#
# [INFO] Win 100.00% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 100.00% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 100.00% at inner_epoch 35
# Converged at inner epoch 35
#
#
# [INFO] Win 93.75% at inner_epoch 44
# Converged at inner epoch 44
#
#
# [INFO] Win 100.00% at inner_epoch 49
# Converged at inner epoch 49
#
#
# [INFO] Win 100.00% at inner_epoch 47
# Converged at inner epoch 47
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 41
# Converged at inner epoch 41
#
#
# [INFO] Win 87.50% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 96.88% at inner_epoch 50
# Converged at inner epoch 50
#
#
# [INFO] Win 100.00% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 100.00% at inner_epoch 37
# Converged at inner epoch 37
#
#
# [INFO] Win 87.50% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 96.88% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 31
# Converged at inner epoch 31
#
#
# [INFO] Win 96.88% at inner_epoch 65
# Converged at inner epoch 65
#
#
# [INFO] Win 100.00% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 84.38% at inner_epoch 4
# Converged at inner epoch 4
#
#
# [INFO] Win 100.00% at inner_epoch 11
# Converged at inner epoch 11
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 87.50% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 42
# Converged at inner epoch 42
#
#
# [INFO] Win 96.88% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 61
# Converged at inner epoch 61
#
#
# [INFO] Win 100.00% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 51
# Converged at inner epoch 51
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 96.88% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 100.00% at inner_epoch 45
# Converged at inner epoch 45
#
#
# [INFO] Win 93.75% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 100.00% at inner_epoch 2
# Converged at inner epoch 2
#
#
# [INFO] Win 100.00% at inner_epoch 31
# Converged at inner epoch 31
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 100.00% at inner_epoch 67
# Converged at inner epoch 67
#
#
# [INFO] Win 100.00% at inner_epoch 24
# Converged at inner epoch 24
#
#
# [INFO] Win 100.00% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 96.88% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 100.00% at inner_epoch 41
# Converged at inner epoch 41
#
#
# [INFO] Win 100.00% at inner_epoch 40
# Converged at inner epoch 40
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 100.00% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 59
# Converged at inner epoch 59
#
#
# [INFO] Win 100.00% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 100.00% at inner_epoch 2
# Converged at inner epoch 2
#
#
# [INFO] Win 100.00% at inner_epoch 37
# Converged at inner epoch 37
#
#
# [INFO] Win 100.00% at inner_epoch 99
# Failed to converge
#
#
# [INFO] Win 100.00% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 56
# Converged at inner epoch 56
#
#
# [INFO] Win 100.00% at inner_epoch 72
# Converged at inner epoch 72
#
#
# [INFO] Win 96.88% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 100.00% at inner_epoch 57
# Converged at inner epoch 57
#
#
# [INFO] Win 100.00% at inner_epoch 47
# Converged at inner epoch 47
#
#
# [INFO] Win 100.00% at inner_epoch 69
# Converged at inner epoch 69
#
#
# [INFO] Win 93.75% at inner_epoch 49
# Converged at inner epoch 49
#
#
# [INFO] Win 100.00% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 52
# Converged at inner epoch 52
#
#
# [INFO] Win 100.00% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 96.88% at inner_epoch 38
# Converged at inner epoch 38
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 48
# Converged at inner epoch 48
#
#
# [INFO] Win 81.25% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 46
# Converged at inner epoch 46
#
#
# [INFO] Win 100.00% at inner_epoch 40
# Converged at inner epoch 40
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 100.00% at inner_epoch 48
# Converged at inner epoch 48
#
#
# [INFO] Win 100.00% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 93.75% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 56
# Converged at inner epoch 56
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 83
# Converged at inner epoch 83
#
#
# [INFO] Win 100.00% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 39
# Converged at inner epoch 39
#
#
# [INFO] Win 93.75% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 44
# Converged at inner epoch 44
#
#
# [INFO] Win 100.00% at inner_epoch 45
# Converged at inner epoch 45
#
#
# [INFO] Win 100.00% at inner_epoch 24
# Converged at inner epoch 24
#
#
# [INFO] Win 87.50% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 60
# Converged at inner epoch 60
#
#
# [INFO] Win 100.00% at inner_epoch 91
# Converged at inner epoch 91
#
#
# [INFO] Win 100.00% at inner_epoch 37
# Converged at inner epoch 37
#
#
# [INFO] Win 100.00% at inner_epoch 37
# Converged at inner epoch 37
#
#
# [INFO] Win 90.62% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 58
# Converged at inner epoch 58
#
#
# [INFO] Win 100.00% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 100.00% at inner_epoch 39
# Converged at inner epoch 39
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 99
# Failed to converge
#
#
# [INFO] Win 100.00% at inner_epoch 70
# Converged at inner epoch 70
#
#
# [INFO] Win 100.00% at inner_epoch 32
# Converged at inner epoch 32
#
#
# [INFO] Win 100.00% at inner_epoch 53
# Converged at inner epoch 53
#
#
# [INFO] Win 100.00% at inner_epoch 42
# Converged at inner epoch 42
#
#
# [INFO] Win 100.00% at inner_epoch 54
# Converged at inner epoch 54
#
#
# [INFO] Win 100.00% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 100.00% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 96.88% at inner_epoch 75
# Converged at inner epoch 75
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 93.75% at inner_epoch 40
# Converged at inner epoch 40
#
#
# [INFO] Win 100.00% at inner_epoch 45
# Converged at inner epoch 45
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 96.88% at inner_epoch 99
# Failed to converge
#
#
# [INFO] Win 100.00% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 49
# Converged at inner epoch 49
#
#
# [INFO] Win 100.00% at inner_epoch 70
# Converged at inner epoch 70
#
#
# [INFO] Win 100.00% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [ERROR] Fail! 78.12% at inner_epoch 99
# Failed to converge
#
#
# [INFO] Win 100.00% at inner_epoch 45
# Converged at inner epoch 45
#
#
# [INFO] Win 84.38% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 40
# Converged at inner epoch 40
#
#
# [INFO] Win 93.75% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 49
# Converged at inner epoch 49
#
#
# [INFO] Win 96.88% at inner_epoch 31
# Converged at inner epoch 31
#
#
# [INFO] Win 90.62% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 39
# Converged at inner epoch 39
#
#
# [INFO] Win 100.00% at inner_epoch 40
# Converged at inner epoch 40
#
#
# [INFO] Win 100.00% at inner_epoch 68
# Converged at inner epoch 68
#
#
# [INFO] Win 96.88% at inner_epoch 55
# Converged at inner epoch 55
#
#
# [INFO] Win 100.00% at inner_epoch 44
# Converged at inner epoch 44
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 100.00% at inner_epoch 61
# Converged at inner epoch 61
#
#
# [INFO] Win 100.00% at inner_epoch 43
# Converged at inner epoch 43
#
#
# [INFO] Win 100.00% at inner_epoch 45
# Converged at inner epoch 45
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 96.88% at inner_epoch 39
# Converged at inner epoch 39
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 45
# Converged at inner epoch 45
#
#
# [INFO] Win 100.00% at inner_epoch 50
# Converged at inner epoch 50
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 84.38% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 80
# Converged at inner epoch 80
#
#
# [INFO] Win 96.88% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 100.00% at inner_epoch 32
# Converged at inner epoch 32
#
#
# [INFO] Win 100.00% at inner_epoch 78
# Converged at inner epoch 78
#
#
# [INFO] Win 96.88% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 73
# Converged at inner epoch 73
#
#
# [INFO] Win 100.00% at inner_epoch 80
# Converged at inner epoch 80
#
#
# [INFO] Win 100.00% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 90.62% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 24
# Converged at inner epoch 24
#
#
# [INFO] Win 100.00% at inner_epoch 38
# Converged at inner epoch 38
#
#
# [INFO] Win 100.00% at inner_epoch 39
# Converged at inner epoch 39
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 42
# Converged at inner epoch 42
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 90.62% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 100.00% at inner_epoch 52
# Converged at inner epoch 52
#
#
# [INFO] Win 90.62% at inner_epoch 3
# Converged at inner epoch 3
#
#
# [INFO] Win 100.00% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 96.88% at inner_epoch 30
# Converged at inner epoch 30
#
#
# [INFO] Win 100.00% at inner_epoch 41
# Converged at inner epoch 41
#
#
# [INFO] Win 100.00% at inner_epoch 59
# Converged at inner epoch 59
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 33
# Converged at inner epoch 33
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 96.88% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 90.62% at inner_epoch 99
# Failed to converge
#
#
# [INFO] Win 96.88% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 96.88% at inner_epoch 39
# Converged at inner epoch 39
#
#
# [INFO] Win 100.00% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 55
# Converged at inner epoch 55
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 99
# Converged at inner epoch 99
#
#
# [INFO] Win 96.88% at inner_epoch 99
# Failed to converge
#
#
# [INFO] Win 100.00% at inner_epoch 51
# Converged at inner epoch 51
#
#
# [INFO] Win 100.00% at inner_epoch 38
# Converged at inner epoch 38
#
#
# [INFO] Win 100.00% at inner_epoch 99
# Failed to converge
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 100.00% at inner_epoch 54
# Converged at inner epoch 54
#
#
# [INFO] Win 100.00% at inner_epoch 90
# Converged at inner epoch 90
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 100.00% at inner_epoch 34
# Converged at inner epoch 34
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 100.00% at inner_epoch 28
# Converged at inner epoch 28
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
# ...
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 9
# Converged at inner epoch 9
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 3
# Converged at inner epoch 3
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 22
# Converged at inner epoch 22
#
#
# [INFO] Win 100.00% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 100.00% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 3
# Converged at inner epoch 3
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 100.00% at inner_epoch 4
# Converged at inner epoch 4
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 27
# Converged at inner epoch 27
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 26
# Converged at inner epoch 26
#
#
# [INFO] Win 100.00% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 4
# Converged at inner epoch 4
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 9
# Converged at inner epoch 9
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 4
# Converged at inner epoch 4
#
#
# [INFO] Win 100.00% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 3
# Converged at inner epoch 3
#
#
# [INFO] Win 100.00% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 4
# Converged at inner epoch 4
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 2
# Converged at inner epoch 2
#
#
# [INFO] Win 100.00% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 9
# Converged at inner epoch 9
#
#
# [INFO] Win 100.00% at inner_epoch 9
# Converged at inner epoch 9
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 4
# Converged at inner epoch 4
#
#
# [INFO] Win 100.00% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 100.00% at inner_epoch 11
# Converged at inner epoch 11
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 3
# Converged at inner epoch 3
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 4
# Converged at inner epoch 4
#
#
# [INFO] Win 100.00% at inner_epoch 9
# Converged at inner epoch 9
#
#
# [INFO] Win 100.00% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 11
# Converged at inner epoch 11
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 25
# Converged at inner epoch 25
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 100.00% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 100.00% at inner_epoch 3
# Converged at inner epoch 3
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 3
# Converged at inner epoch 3
#
#
# [INFO] Win 100.00% at inner_epoch 4
# Converged at inner epoch 4
#
#
# [INFO] Win 100.00% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 21
# Converged at inner epoch 21
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 4
# Converged at inner epoch 4
#
#
# [INFO] Win 100.00% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 9
# Converged at inner epoch 9
#
#
# [INFO] Win 100.00% at inner_epoch 9
# Converged at inner epoch 9
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 100.00% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 100.00% at inner_epoch 11
# Converged at inner epoch 11
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 11
# Converged at inner epoch 11
#
#
# [INFO] Win 100.00% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 9
# Converged at inner epoch 9
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 24
# Converged at inner epoch 24
#
#
# [INFO] Win 100.00% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 4
# Converged at inner epoch 4
#
#
# [INFO] Win 100.00% at inner_epoch 9
# Converged at inner epoch 9
#
#
# [INFO] Win 100.00% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 6
# Converged at inner epoch 6
#
#
# [INFO] Win 100.00% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 20
# Converged at inner epoch 20
#
#
# [INFO] Win 100.00% at inner_epoch 9
# Converged at inner epoch 9
#
#
# [INFO] Win 100.00% at inner_epoch 14
# Converged at inner epoch 14
#
#
# [INFO] Win 100.00% at inner_epoch 11
# Converged at inner epoch 11
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 11
# Converged at inner epoch 11
#
#
# [INFO] Win 100.00% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 29
# Converged at inner epoch 29
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 4
# Converged at inner epoch 4
#
#
# [INFO] Win 100.00% at inner_epoch 17
# Converged at inner epoch 17
#
#
# [INFO] Win 100.00% at inner_epoch 23
# Converged at inner epoch 23
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 19
# Converged at inner epoch 19
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 100.00% at inner_epoch 15
# Converged at inner epoch 15
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 11
# Converged at inner epoch 11
#
#
# [INFO] Win 100.00% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 18
# Converged at inner epoch 18
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 1
# Converged at inner epoch 1
#
#
# [INFO] Win 100.00% at inner_epoch 5
# Converged at inner epoch 5
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
#
#
# [INFO] Win 100.00% at inner_epoch 16
# Converged at inner epoch 16
#
#
# [INFO] Win 100.00% at inner_epoch 11
# Converged at inner epoch 11
#
#
# [INFO] Win 100.00% at inner_epoch 4
# Converged at inner epoch 4
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 11
# Converged at inner epoch 11
#
#
# [INFO] Win 100.00% at inner_epoch 12
# Converged at inner epoch 12
#
#
# [INFO] Win 100.00% at inner_epoch 4
# Converged at inner epoch 4
#
#
# [INFO] Win 100.00% at inner_epoch 8
# Converged at inner epoch 8
#
#
# [INFO] Win 100.00% at inner_epoch 4
# Converged at inner epoch 4
#
#
# [INFO] Win 100.00% at inner_epoch 7
# Converged at inner epoch 7
#
#
# [INFO] Win 100.00% at inner_epoch 13
# Converged at inner epoch 13
#
#
# [INFO] Win 100.00% at inner_epoch 10
# Converged at inner epoch 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 train_model(
#       2     net,
#       3     control_net,
#       4     train_loader,
#       5     criterion,
#       6     control_optimizer,
#       7     net_optimizer,
#       8     control_threshold,
#       9     l1_lambda,
#      10 )
#
# Cell In[9], line 44, in train_model(net, control_net, train_loader, criterion, control_optimizer, net_optimizer, control_threshold, l1_lambda)
#      40 control_loss = criterion(output, batch_labels)
#      42 # l1_reg = l1_lambda * (net(data) - label).abs().sum(dim=1).mean()
# ---> 44 control_loss.backward()
#      46 control_optimizer.step()
#      47 net_optimizer.step()
#
# File ~\python-envs\deep-learning\Lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File ~\python-envs\deep-learning\Lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~\python-envs\deep-learning\Lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:
